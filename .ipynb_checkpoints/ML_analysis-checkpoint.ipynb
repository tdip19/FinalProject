# %%
import pandas as pd 

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
merged = pd.read_csv('inputs/merged.csv')

# %%
merged
# Out:
#     Year Period      Label  SP500_Return  Percent_Change_in_GDP         CPI  \
# 0   2005    Q01  2005 Qtr1       -0.0259                    4.5  192.366667
# 1   2005    Q02  2005 Qtr2        0.0091                    2.0  193.666667
# 2   2005    Q03  2005 Qtr3        0.0315                    3.2  196.600000
# 3   2005    Q04  2005 Qtr4        0.0159                    2.3  198.433333
# 4   2006    Q01  2006 Qtr1        0.0373                    5.5  199.466667
# ..   ...    ...        ...           ...                    ...         ...
# 67  2021    Q04  2021 Qtr4        0.1040                    7.0  278.706667
# 68  2022    Q01  2022 Qtr1       -0.0518                   -1.6  284.893667
# 69  2022    Q02  2022 Qtr2       -0.1663                   -0.6  291.535667
# 70  2022    Q03  2022 Qtr3       -0.0517                    3.2  295.495667
# 71  2022    Q04  2022 Qtr4        0.0636                    2.6  298.525000
#
#     Construction_Unemployment_Rate  Manufacturing_Unemployment_Rate  \
# 0                             11.4                              5.3
# 1                              6.4                              4.6
# 2                              5.6                              4.9
# 3                              6.4                              4.8
# 4                              8.7                              4.5
# ..                             ...                              ...
# 67                             4.6                              3.1
# 68                             6.6                              3.3
# 69                             4.0                              3.0
# 70                             3.6                              3.1
# 71                             4.1                              2.5
#
#     Finance_Unemployment_Rate
# 0                         2.6
# 1                         3.2
# 2                         3.2
# 3                         2.5
# 4                         2.6
# ..                        ...
# 67                        2.2
# 68                        2.1
# 69                        1.5
# 70                        1.2
# 71                        1.7
#
# [72 rows x 9 columns]

# %% [markdown]
# ## Rough Outline
#
# 1. training set for the data
# 1. need to impute missing data
# 1. test set for the data

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score
from sklearn.pipeline import Pipeline
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder 
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline 
from sklearn.impute import SimpleImputer
#from df_after_transform import df_after_transform
from sklearn.model_selection import KFold, cross_validate, GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV 
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer



from sklearn import set_config
set_config(display="diagram")  # display='text' is the default

pd.set_option('display.max_colwidth', 1000, 'display.max_rows', 50, 'display.max_columns', None)

# %%
#preprop: splitting into training and test: 
# X_train, X_test, y_train, y_test = train_test_split(merged.drop('Finance Unemployment Rate', axis=1), merged['Finance Unemployment Rate'], test_size=0.2, random_state=42)

recession_df = pd.read_csv('inputs/merged.csv')
recession_df 

X = recession_df[['SP500_Return', 'Percent_Change_in_GDP', 'CPI']]
y = recession_df['Finance_Unemployment_Rate'] 

X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3)

# %%
# ML for finance, using 70% as train and .3 as test   
model = LinearRegression()
model.fit(X_train,y_train)

predictions = model.predict(X_test)

#print(predictions)

predictions
# Out:
# array([3.77463112, 2.9506766 , 3.66237929, 3.54781538, 3.09309114,
#        4.51088787, 3.54351766, 3.40756423, 2.31061557, 4.77456976,
#        3.36566515, 3.32996576, 3.83340164, 4.62443792, 0.92517135,
#        1.1887856 , 2.97346488, 4.13789556, 3.23946066, 4.77929956,
#        3.4438957 , 4.77894128])

# %% [markdown]
# # ML using just the regressions:

# %%
# ML for construction, working data using linear regression: 

X = recession_df[['SP500_Return', 'Percent_Change_in_GDP', 'CPI']]
y = recession_df['Construction_Unemployment_Rate']

model = LinearRegression()
model.fit(X,y)

predictions = model.predict(X) 
recession_df['Predicted_Construction_Unemployment_Rate'] = predictions
#recession_df = recession_df.drop('Predicted_Finance_Unemployment_Rate', axis=1)

# %%
# ML for manuf, working data using linear regression: 

X = recession_df[['SP500_Return', 'Percent_Change_in_GDP', 'CPI']]
y = recession_df['Manufacturing_Unemployment_Rate']

model = LinearRegression()
model.fit(X,y)

predictions = model.predict(X) 
recession_df['Predicted_Manufacturing_Unemployment_Rate'] = predictions
#recession_df = recession_df.drop('Predicted_Finance_Unemployment_Rate', axis=1)

# %%
# ML for finance, working data using linear regression: 

X = recession_df[['SP500_Return', 'Percent_Change_in_GDP', 'CPI']]
y = recession_df['Finance_Unemployment_Rate']

model = LinearRegression()
model.fit(X,y)

predictions = model.predict(X) 
recession_df['Predicted_Finance_Unemployment_Rate'] = predictions
recession_df
# Out:
#     Year Period      Label  SP500_Return  Percent_Change_in_GDP         CPI  \
# 0   2005    Q01  2005 Qtr1       -0.0259                    4.5  192.366667
# 1   2005    Q02  2005 Qtr2        0.0091                    2.0  193.666667
# 2   2005    Q03  2005 Qtr3        0.0315                    3.2  196.600000
# 3   2005    Q04  2005 Qtr4        0.0159                    2.3  198.433333
# 4   2006    Q01  2006 Qtr1        0.0373                    5.5  199.466667
# ..   ...    ...        ...           ...                    ...         ...
# 67  2021    Q04  2021 Qtr4        0.1040                    7.0  278.706667
# 68  2022    Q01  2022 Qtr1       -0.0518                   -1.6  284.893667
# 69  2022    Q02  2022 Qtr2       -0.1663                   -0.6  291.535667
# 70  2022    Q03  2022 Qtr3       -0.0517                    3.2  295.495667
# 71  2022    Q04  2022 Qtr4        0.0636                    2.6  298.525000
#
#     Construction_Unemployment_Rate  Manufacturing_Unemployment_Rate  \
# 0                             11.4                              5.3
# 1                              6.4                              4.6
# 2                              5.6                              4.9
# 3                              6.4                              4.8
# 4                              8.7                              4.5
# ..                             ...                              ...
# 67                             4.6                              3.1
# 68                             6.6                              3.3
# 69                             4.0                              3.0
# 70                             3.6                              3.1
# 71                             4.1                              2.5
#
#     Finance_Unemployment_Rate  Predicted_Construction_Unemployment_Rate  \
# 0                         2.6                                 12.571252
# 1                         3.2                                 13.026053
# 2                         3.2                                 12.820924
# 3                         2.5                                 12.632145
# 4                         2.6                                 12.361589
# ..                        ...                                       ...
# 67                        2.2                                  5.819398
# 68                        2.1                                  4.950306
# 69                        1.5                                  3.311401
# 70                        1.2                                  3.488665
# 71                        1.7                                  4.244180
#
#     Predicted_Manufacturing_Unemployment_Rate  \
# 0                                    6.929802
# 1                                    7.320820
# 2                                    7.266847
# 3                                    7.146438
# 4                                    7.010912
# ..                                        ...
# 67                                   4.046022
# 68                                   3.323162
# 69                                   2.139439
# 70                                   2.508093
# 71                                   3.260177
#
#     Predicted_Finance_Unemployment_Rate
# 0                              4.630763
# 1                              4.696322
# 2                              4.622378
# 3                              4.559514
# 4                              4.502573
# ..                                  ...
# 67                             2.219427
# 68                             1.945694
# 69                             1.542854
# 70                             1.538445
# 71                             1.646589
#
# [72 rows x 12 columns]

# %%
#R2 

r2_con = r2_score(recession_df['Construction_Unemployment_Rate'], recession_df['Predicted_Construction_Unemployment_Rate'])
r2_manuf = r2_score(recession_df['Manufacturing_Unemployment_Rate'], recession_df['Predicted_Manufacturing_Unemployment_Rate'])
r2_fin = r2_score(recession_df['Finance_Unemployment_Rate'], recession_df['Predicted_Finance_Unemployment_Rate'])

print('R2 Score Construction:', r2_con, 
      'R2 Score Manufacturing:', r2_manuf,
     'R2 Score Finance:', r2_fin
     )
# Out:
# R2 Score Construction: 0.20853568450049698 R2 Score Manufacturing: 0.22290384238480077 R2 Score Finance: 0.22360609989705205

# %%
data = {'Industry': ['Construction', 'Manuf', 'Fin'],
        'R2': [r2_con, r2_manuf, r2_fin]}

reg_df = pd.DataFrame(data)
reg_df
# Out:
#        Industry        R2
# 0  Construction  0.208536
# 1         Manuf  0.222904
# 2           Fin  0.223606

# %% [markdown]
# # Better Machine Learning:
#
# - The ML above is just fitting the predicitos along the line of best fit. This is not ideal and doesnt tell us much.
# - Below we use pipelines based on the different variables

# %% [markdown]
# ## Construction

# %%
#Construction 

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.model_selection import GridSearchCV
from sklearn import metrics


X_train_c, X_test_c, y_train_c, y_test_c = train_test_split(
    merged.drop('Construction_Unemployment_Rate', axis=1),
    merged['Construction_Unemployment_Rate'],
    test_size=0.3,
    stratify=merged['Year']
) 

# Define the preprocessing steps for the numerical and categorical columns
num_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

cat_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
]) 

# Combine the preprocessing steps using ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('num', num_transformer, ['SP500_Return', 'Percent_Change_in_GDP', 'CPI']),
    ('cat', cat_transformer, ['Year', 'Period'])
]) 

# Define the model as a pipeline of the preprocessor and a linear regression model
model_c = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
]) 

# Train the model on the training data
model_c.fit(X_train_c, y_train_c)

# Predict on the testing data
y_pred_c = model_c.predict(X_test_c)

# Evaluate the model
score_c = model_c.score(X_test_c, y_test_c)
print(f'R^2 score: {score_c}') 

print(y_pred_c)
len(X_train_c)

#####
# Out:
# R^2 score: 0.7695226168852791
# [10.16356892  5.95139505  6.84938576 21.3721612  15.66847146  4.37912837
#  -1.36057286  5.69876721 11.8484639   7.62328454 11.86858085  4.08764825
#   9.29860911  6.64601198  6.57547072  9.45833403 17.20101979  4.82816344
#  12.55056301  3.68839336 16.08312475  5.02443735]
# 50

# %%
merged
# Out:
#     Year Period      Label  SP500_Return  Percent_Change_in_GDP         CPI  \
# 0   2005    Q01  2005 Qtr1       -0.0259                    4.5  192.366667
# 1   2005    Q02  2005 Qtr2        0.0091                    2.0  193.666667
# 2   2005    Q03  2005 Qtr3        0.0315                    3.2  196.600000
# 3   2005    Q04  2005 Qtr4        0.0159                    2.3  198.433333
# 4   2006    Q01  2006 Qtr1        0.0373                    5.5  199.466667
# ..   ...    ...        ...           ...                    ...         ...
# 67  2021    Q04  2021 Qtr4        0.1040                    7.0  278.706667
# 68  2022    Q01  2022 Qtr1       -0.0518                   -1.6  284.893667
# 69  2022    Q02  2022 Qtr2       -0.1663                   -0.6  291.535667
# 70  2022    Q03  2022 Qtr3       -0.0517                    3.2  295.495667
# 71  2022    Q04  2022 Qtr4        0.0636                    2.6  298.525000
#
#     Construction_Unemployment_Rate  Manufacturing_Unemployment_Rate  \
# 0                             11.4                              5.3
# 1                              6.4                              4.6
# 2                              5.6                              4.9
# 3                              6.4                              4.8
# 4                              8.7                              4.5
# ..                             ...                              ...
# 67                             4.6                              3.1
# 68                             6.6                              3.3
# 69                             4.0                              3.0
# 70                             3.6                              3.1
# 71                             4.1                              2.5
#
#     Finance_Unemployment_Rate
# 0                         2.6
# 1                         3.2
# 2                         3.2
# 3                         2.5
# 4                         2.6
# ..                        ...
# 67                        2.2
# 68                        2.1
# 69                        1.5
# 70                        1.2
# 71                        1.7
#
# [72 rows x 9 columns]

# %% [markdown]
# ## Manufacturing

# %%
#Manufacturing

X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(
    merged.drop('Manufacturing_Unemployment_Rate', axis=1),
    merged['Manufacturing_Unemployment_Rate'],
    test_size=0.3,
    stratify=merged['Year']
) 

# Define the preprocessing steps for the numerical and categorical columns
num_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

cat_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
]) 

# Combine the preprocessing steps using ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('num', num_transformer, ['SP500_Return', 'Percent_Change_in_GDP', 'CPI']),
    ('cat', cat_transformer, ['Year', 'Period'])
]) 

# Define the model as a pipeline of the preprocessor and a linear regression model
model_m = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
]) 

# Train the model on the training data
model_m.fit(X_train_m, y_train_m)

# Predict on the testing data
y_pred_m = model_m.predict(X_test_m)

# Evaluate the model
score_m = model_m.score(X_test_m, y_test_m)
print(f'R^2 score: {score_m}') 

print(y_pred_m)
len(X_train_m)
# Out:
# R^2 score: 0.5164973690393078
# [11.84422918  6.70980268  4.70572902  4.24945697  2.7315832  12.83861473
#   4.92893184  5.04669169  2.92334771  0.67444712  8.11865406  4.97972168
#   6.26601185  3.1169502   8.44246064  4.27647447  5.21241318  4.68366998
#   1.90002704  4.64445433  5.19423156  3.91579357]
# 50

# %% [markdown]
# # Finance

# %%
#Fin 


X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(
    merged.drop('Finance_Unemployment_Rate', axis=1),
    merged['Finance_Unemployment_Rate'],
    test_size=0.3,
    stratify=merged['Year']
) 

# Define the preprocessing steps for the numerical and categorical columns
num_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

cat_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
]) 

# Combine the preprocessing steps using ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('num', num_transformer, ['SP500_Return', 'Percent_Change_in_GDP', 'CPI']),
    ('cat', cat_transformer, ['Year', 'Period'])
]) 

# Define the model as a pipeline of the preprocessor and a linear regression model
model_f = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
]) 

# Train the model on the training data
model_f.fit(X_train_f, y_train_f)

# Predict on the testing data
y_pred_f = model_f.predict(X_test_f)

# Evaluate the model
score_f = model_f.score(X_test_f, y_test_f)
print(f'R^2 score: {score_f}') 

print(y_pred_f)
len(X_train_f)
# Out:
# R^2 score: 0.6626500042211674
# [2.57516154 2.77411089 4.72128584 2.57018426 2.70735319 3.17848799
#  1.93222672 3.98076137 2.19246218 2.70558232 2.73130508 3.46942625
#  2.85874486 4.44164368 7.33445638 3.22442006 1.77509454 1.89215279
#  7.32512185 4.1815822  6.27548333 3.23960441]
# 50

# %%
#### PLayaround

X_train, X_test, y_train, y_test = train_test_split(
    merged.drop('Manufacturing Unemployment Rate', axis=1),
    merged['Manufacturing Unemployment Rate'],
    test_size=0.3,
    stratify=merged['Year']
) 

# Define the preprocessing steps for the numerical and categorical columns
num_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

cat_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
]) 

# Combine the preprocessing steps using ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('num', num_transformer, ['S&P500 Return', 'Percent Change in GDP', 'CPI']),
    ('cat', cat_transformer, ['Year', 'Period'])
]) 

# Define the model as a pipeline of the preprocessor and a linear regression model
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
]) 

# Train the model on the training data
model.fit(X_train, y_train)

# Predict on the testing data
y_pred = model.predict(X_test)

# Evaluate the model
score = model.score(X_test, y_test)
print(f'R^2 score: {score}') 

#print(y_pred)
len(X_train) 
###

from sklearn.model_selection import GridSearchCV

# Define the hyperparameters and values to search over
hyperparameters = {
    'preprocessor__num__scaler__with_mean': [True, False],
    'preprocessor__num__scaler__with_std': [True, False],
    'preprocessor__cat__onehot__drop': ['first', None],
    'regressor__fit_intercept': [True, False]
}

# Create a GridSearchCV object with the pipeline and hyperparameters to search over
search = GridSearchCV(model, hyperparameters, scoring='r2', cv=5)

# Fit the GridSearchCV object to the training data to find the best hyperparameters
search.fit(X_train, y_train)

# Print the best hyperparameters and score
print(f'Best parameters: {search.best_params_}')
print(f'R^2 score: {search.best_score_}')

# Use the best model to make predictions on the test data
best_model = search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate the best model
score = best_model.score(X_test, y_test)
print(f'R^2 score: {score}')
# Out:
# R^2 score: 0.7108498752899844
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /Users/thomasgriffith/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:170: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# Best parameters: {'preprocessor__cat__onehot__drop': None, 'preprocessor__num__scaler__with_mean': True, 'preprocessor__num__scaler__with_std': False, 'regressor__fit_intercept': True}
# R^2 score: 0.3459119100650088
# R^2 score: 0.710842845822272

# %%
#Construction 

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.model_selection import GridSearchCV
from sklearn import metrics


X_train, X_test, y_train, y_test = train_test_split(
    merged.drop('Construction Unemployment Rate', axis=1),
    merged['Construction Unemployment Rate'],
    test_size=0.3,
    stratify=merged['Year']
) 

# Define the preprocessing steps for the numerical and categorical columns
num_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

cat_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
]) 

# Combine the preprocessing steps using ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('num', num_transformer, ['S&P500 Return', 'Percent Change in GDP', 'CPI']),
    ('cat', cat_transformer, ['Year', 'Period'])
]) 

# Define the model as a pipeline of the preprocessor and a linear regression model
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
]) 

# Train the model on the training data
model.fit(X_train, y_train)

# Predict on the testing data
y_pred = model.predict(X_test)

# Evaluate the model
score = model.score(X_test, y_test)
print(f'R^2 score: {score}') 

print(y_pred)
len(X_train)

#####

sample_data = pd.DataFrame({
    'S&P500 Return': [-0.0259, 0.0091],
    'Percent Change in GDP': [4.5, 2.0],
    'CPI': [192.366667, 193.666667]
})

# Get predictions for the sample data
predictions = model.predict(sample_data)

# Print the predictions
print(predictions)
# Out:
# R^2 score: 0.8330482753628743
# [14.54063572  5.02211262 12.15538213  6.34638383  8.14367769  4.35612338
#   4.14193998 15.88776381  4.12490516 17.9465364  19.78745418  6.09577191
#   0.48002432  5.78459548  8.93846498 10.70083545 21.17545315  7.0897467
#   9.12041094  6.32238908  8.79468236 12.37354921]
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     821             try:
# --> 822                 tasks = self._ready_batches.get(block=False)
#     823             except queue.Empty:
#
# ~/opt/anaconda3/lib/python3.9/queue.py in get(self, block, timeout)
#     167                 if not self._qsize():
# --> 168                     raise Empty
#     169             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/vs/l7j3vthx4pn_y5nlywqywjvm0000gn/T/ipykernel_4097/2434904835.py in <module>
#      62
#      63 # Get predictions for the sample data
# ---> 64 predictions = model.predict(sample_data)
#      65
#      66 # Print the predictions
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     111
#     112             # lambda, but not partial, allows help() to work with update_wrapper
# --> 113             out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     114         else:
#     115
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py in predict(self, X, **predict_params)
#     467         Xt = X
#     468         for _, name, transform in self._iter(with_final=False):
# --> 469             Xt = transform.transform(Xt)
#     470         return self.steps[-1][1].predict(Xt, **predict_params)
#     471
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in transform(self, X)
#     746             self._check_n_features(X, reset=False)
#     747
# --> 748         Xs = self._fit_transform(
#     749             X,
#     750             None,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in _fit_transform(self, X, y, func, fitted, column_as_strings)
#     604         )
#     605         try:
# --> 606             return Parallel(n_jobs=self.n_jobs)(
#     607                 delayed(func)(
#     608                     transformer=clone(trans) if not fitted else trans,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     831                 big_batch_size = batch_size * n_jobs
#     832
# --> 833                 islice = list(itertools.islice(iterator, big_batch_size))
#     834                 if len(islice) == 0:
#     835                     return False
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in <genexpr>(.0)
#     607                 delayed(func)(
#     608                     transformer=clone(trans) if not fitted else trans,
# --> 609                     X=_safe_indexing(X, column, axis=1),
#     610                     y=y,
#     611                     weight=weight,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/__init__.py in _safe_indexing(X, indices, axis)
#     374
#     375     if hasattr(X, "iloc"):
# --> 376         return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     377     elif hasattr(X, "shape"):
#     378         return _array_indexing(X, indices, indices_dtype, axis=axis)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/__init__.py in _pandas_indexing(X, key, key_dtype, axis)
#     220         # check whether we should index with loc or iloc
#     221         indexer = X.iloc if key_dtype == "int" else X.loc
# --> 222         return indexer[:, key] if axis else indexer[key]
#     223
#     224
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1147             return self._multi_take(tup)
#    1148
# -> 1149         return self._getitem_tuple_same_dim(tup)
#    1150
#    1151     def _get_label(self, label, axis: int):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     825                 continue
#     826
# --> 827             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828             # We should never have retval.ndim < self.ndim, as that should
#     829             #  be handled by the _getitem_lowerdim call above.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1192                     raise ValueError("Cannot index with multidimensional key")
#    1193
# -> 1194                 return self._getitem_iterable(key, axis=axis)
#    1195
#    1196             # nested tuple slicing
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1130
#    1131         # A collection of keys
# -> 1132         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1133         return self.obj._reindex_with_indexers(
#    1134             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1328         axis_name = self.obj._get_axis_name(axis)
#    1329
# -> 1330         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1331
#    1332         return keyarr, indexer
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Year', 'Period'], dtype='object')] are in the [columns]"

# %%
sample_data = pd.DataFrame({
    'S&P500 Return': [-0.0259, 0.0091],
    'Percent Change in GDP': [4.5, 2.0],
    'CPI': [192.366667, 193.666667]
})

# Get predictions for the sample data
predictions = model.predict(sample_data)

# Print the predictions
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     821             try:
# --> 822                 tasks = self._ready_batches.get(block=False)
#     823             except queue.Empty:
#
# ~/opt/anaconda3/lib/python3.9/queue.py in get(self, block, timeout)
#     167                 if not self._qsize():
# --> 168                     raise Empty
#     169             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/vs/l7j3vthx4pn_y5nlywqywjvm0000gn/T/ipykernel_4097/2129657391.py in <module>
#       6
#       7 # Get predictions for the sample data
# ----> 8 predictions = model.predict(sample_data)
#       9
#      10 # Print the predictions
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     111
#     112             # lambda, but not partial, allows help() to work with update_wrapper
# --> 113             out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     114         else:
#     115
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/pipeline.py in predict(self, X, **predict_params)
#     467         Xt = X
#     468         for _, name, transform in self._iter(with_final=False):
# --> 469             Xt = transform.transform(Xt)
#     470         return self.steps[-1][1].predict(Xt, **predict_params)
#     471
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in transform(self, X)
#     746             self._check_n_features(X, reset=False)
#     747
# --> 748         Xs = self._fit_transform(
#     749             X,
#     750             None,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in _fit_transform(self, X, y, func, fitted, column_as_strings)
#     604         )
#     605         try:
# --> 606             return Parallel(n_jobs=self.n_jobs)(
#     607                 delayed(func)(
#     608                     transformer=clone(trans) if not fitted else trans,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     831                 big_batch_size = batch_size * n_jobs
#     832
# --> 833                 islice = list(itertools.islice(iterator, big_batch_size))
#     834                 if len(islice) == 0:
#     835                     return False
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in <genexpr>(.0)
#     607                 delayed(func)(
#     608                     transformer=clone(trans) if not fitted else trans,
# --> 609                     X=_safe_indexing(X, column, axis=1),
#     610                     y=y,
#     611                     weight=weight,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/__init__.py in _safe_indexing(X, indices, axis)
#     374
#     375     if hasattr(X, "iloc"):
# --> 376         return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     377     elif hasattr(X, "shape"):
#     378         return _array_indexing(X, indices, indices_dtype, axis=axis)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/__init__.py in _pandas_indexing(X, key, key_dtype, axis)
#     220         # check whether we should index with loc or iloc
#     221         indexer = X.iloc if key_dtype == "int" else X.loc
# --> 222         return indexer[:, key] if axis else indexer[key]
#     223
#     224
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1147             return self._multi_take(tup)
#    1148
# -> 1149         return self._getitem_tuple_same_dim(tup)
#    1150
#    1151     def _get_label(self, label, axis: int):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     825                 continue
#     826
# --> 827             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828             # We should never have retval.ndim < self.ndim, as that should
#     829             #  be handled by the _getitem_lowerdim call above.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1192                     raise ValueError("Cannot index with multidimensional key")
#    1193
# -> 1194                 return self._getitem_iterable(key, axis=axis)
#    1195
#    1196             # nested tuple slicing
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1130
#    1131         # A collection of keys
# -> 1132         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1133         return self.obj._reindex_with_indexers(
#    1134             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1328         axis_name = self.obj._get_axis_name(axis)
#    1329
# -> 1330         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1331
#    1332         return keyarr, indexer
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Year', 'Period'], dtype='object')] are in the [columns]"

# %%
'''
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# Define the feature selection step
selector = SelectKBest(f_regression)

# Define the preprocessing steps for the numerical and categorical columns
num_transformer = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('selector', selector)
])

cat_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
]) 

# Combine the preprocessing steps using ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('num', num_transformer, ['S&P500 Return', 'Percent Change in GDP', 'CPI']),
    ('cat', cat_transformer, ['Year', 'Period'])
]) 

# Define the model as a pipeline of the preprocessor and a linear regression model
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
]) 

# Define the hyperparameters and values to search over
hyperparameters = {
    'preprocessor__num__selector__k': [1, 2, 3],
    'regressor__fit_intercept': [True, False],
    'regressor__normalize': [True, False]
}

# Create a GridSearchCV object with the pipeline and hyperparameters to search over
search = GridSearchCV(model, hyperparameters, scoring='r2', cv=5)

# Fit the GridSearchCV object to the training data to find the best hyperparameters
search.fit(X_train, y_train)

# Print the best hyperparameters and score
print(f'Best parameters: {search.best_params_}')
print(f'R^2 score: {search.best_score_}')

# Use the best model to make predictions on the test data
best_model = search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate the best model
score = best_model.score(X_test, y_test)
print(f'R^2 score: {score}') 

'''
# Out:
# "\nfrom sklearn.feature_selection import SelectKBest, f_regression\nfrom sklearn.linear_model import LinearRegression\nfrom sklearn.model_selection import GridSearchCV\nfrom sklearn.pipeline import Pipeline\n\n# Define the feature selection step\nselector = SelectKBest(f_regression)\n\n# Define the preprocessing steps for the numerical and categorical columns\nnum_transformer = Pipeline(steps=[\n    ('scaler', StandardScaler()),\n    ('selector', selector)\n])\n\ncat_transformer = Pipeline(steps=[\n    ('onehot', OneHotEncoder(handle_unknown='ignore'))\n]) \n\n# Combine the preprocessing steps using ColumnTransformer\npreprocessor = ColumnTransformer(transformers=[\n    ('num', num_transformer, ['S&P500 Return', 'Percent Change in GDP', 'CPI']),\n    ('cat', cat_transformer, ['Year', 'Period'])\n]) \n\n# Define the model as a pipeline of the preprocessor and a linear regression model\nmodel = Pipeline(steps=[\n    ('preprocessor', preprocessor),\n    ('regressor', LinearRegression())\n]) \n\n# Define the hyperparameters and values to search over\nhyperparameters = {\n    'preprocessor__num__selector__k': [1, 2, 3],\n    'regressor__fit_intercept': [True, False],\n    'regressor__normalize': [True, False]\n}\n\n# Create a GridSearchCV object with the pipeline and hyperparameters to search over\nsearch = GridSearchCV(model, hyperparameters, scoring='r2', cv=5)\n\n# Fit the GridSearchCV object to the training data to find the best hyperparameters\nsearch.fit(X_train, y_train)\n\n# Print the best hyperparameters and score\nprint(f'Best parameters: {search.best_params_}')\nprint(f'R^2 score: {search.best_score_}')\n\n# Use the best model to make predictions on the test data\nbest_model = search.best_estimator_\ny_pred = best_model.predict(X_test)\n\n# Evaluate the best model\nscore = best_model.score(X_test, y_test)\nprint(f'R^2 score: {score}') \n\n"

# %%
'''

# Split the DataFrame into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(
    merged.drop(['Construction Unemployment Rate', 'Year', 'Period', 'Label'], axis=1),
    merged['Construction Unemployment Rate'],
    test_size=0.2,
    random_state=42,
    stratify=merged[['Year', 'Period']]  # Stratify by year and quarter
)

# Create a pipeline object
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('feature_selection', SelectKBest(f_regression)),
    ('regressor', LinearRegression())
])

# Define hyperparameters to search over
parameters = {
    'feature_selection__k': [2, 3, 4],
    'regressor__normalize': [True, False]
}

# Use GridSearchCV to tune the pipeline
grid_search = GridSearchCV(pipeline, parameters, cv=5)
grid_search.fit(X_train, y_train)

# Evaluate the performance of the pipeline on the test set
y_pred = grid_search.predict(X_test)
mse = metrics.mean_squared_error(y_test, y_pred)
mae = metrics.mean_absolute_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)

print(f'MSE: {mse:.2f}')
print(f'MAE: {mae:.2f}')
print(f'R^2: {r2:.2f}')

'''
# Out:
# "\n\n# Split the DataFrame into a training set and a test set\nX_train, X_test, y_train, y_test = train_test_split(\n    merged.drop(['Construction Unemployment Rate', 'Year', 'Period', 'Label'], axis=1),\n    merged['Construction Unemployment Rate'],\n    test_size=0.2,\n    random_state=42,\n    stratify=merged[['Year', 'Period']]  # Stratify by year and quarter\n)\n\n# Create a pipeline object\npipeline = Pipeline([\n    ('scaler', StandardScaler()),\n    ('feature_selection', SelectKBest(f_regression)),\n    ('regressor', LinearRegression())\n])\n\n# Define hyperparameters to search over\nparameters = {\n    'feature_selection__k': [2, 3, 4],\n    'regressor__normalize': [True, False]\n}\n\n# Use GridSearchCV to tune the pipeline\ngrid_search = GridSearchCV(pipeline, parameters, cv=5)\ngrid_search.fit(X_train, y_train)\n\n# Evaluate the performance of the pipeline on the test set\ny_pred = grid_search.predict(X_test)\nmse = metrics.mean_squared_error(y_test, y_pred)\nmae = metrics.mean_absolute_error(y_test, y_pred)\nr2 = metrics.r2_score(y_test, y_pred)\n\nprint(f'MSE: {mse:.2f}')\nprint(f'MAE: {mae:.2f}')\nprint(f'R^2: {r2:.2f}')\n\n"

# %% [markdown]
# ## Test on random data

# %%
data_random_10 = pd.read_csv('inputs/data_random_10.csv')
data_random_10
# Out:
#     Year Period  SP500_Return  Percent_Change_in_GDP     CPI
# 0   2023    Q01         -0.11                 -16.40  244.45
# 1   2023    Q02          0.06                 -12.07  278.60
# 2   2023    Q03         -0.01                 -17.79  309.32
# 3   2023    Q04          0.13                  11.02  285.51
# 4   2024    Q01          0.12                   7.18  295.33
# 5   2024    Q02         -0.07                   3.85  213.16
# 6   2024    Q03         -0.07                 -17.40  283.26
# 7   2024    Q04          0.13                   5.61  311.66
# 8   2025    Q01          0.19                  -5.67  292.09
# 9   2025    Q02          0.16                   2.85  264.84
# 10  2025    Q03         -0.04                 -14.66  215.66
# 11  2025    Q04          0.02                   7.38  269.45
# 12  2026    Q01          0.09                   5.70  270.23
# 13  2026    Q02          0.10                 -20.66  323.40
# 14  2026    Q03         -0.04                   7.65  254.89
# 15  2026    Q04          0.04                  21.45  263.34
# 16  2027    Q01          0.02                  15.70  265.71
# 17  2027    Q02         -0.17                  22.49  282.68
# 18  2027    Q03          0.12                  24.55  214.39
# 19  2027    Q04          0.16                  16.92  294.14
# 20  2028    Q01         -0.04                  -7.03  288.75
# 21  2028    Q02          0.06                   8.36  290.10
# 22  2028    Q03         -0.15                   1.40  282.27
# 23  2028    Q04         -0.04                 -10.99  264.04
# 24  2029    Q01          0.18                  -3.05  333.33
# 25  2029    Q02          0.07                 -18.23  222.49
# 26  2029    Q03         -0.03                   0.32  202.03
# 27  2029    Q04          0.13                  25.73  281.65
# 28  2030    Q01         -0.06                 -14.02  210.07
# 29  2030    Q02          0.04                 -14.93  318.01
# 30  2030    Q03          0.16                  14.29  250.49
# 31  2030    Q04         -0.01                   6.40  222.57
# 32  2031    Q01          0.13                   1.30  265.10
# 33  2031    Q02         -0.12                 -14.24  298.91
# 34  2031    Q03          0.09                 -10.14  314.16
# 35  2031    Q04          0.09                  21.47  236.86
# 36  2032    Q01         -0.09                  -1.19  234.89
# 37  2032    Q02          0.18                   4.48  233.94
# 38  2032    Q03         -0.01                 -19.65  307.52
# 39  2032    Q04          0.17                  -7.04  299.70

# %%
# Predict new random unemployment for construction

# Train the model on the training data
model_c.fit(X_train_c, y_train_c)

# Predict on the testing data
pred_random = model_c.predict(data_random_10)

data_random_10['Construction_Unemployment_Pred'] = pred_random

# %%
# Predict new random unemployment for manufacturing

# Train the model on the training data
model_m.fit(X_train_m, y_train_m)

# Predict on the testing data
pred_random = model_m.predict(data_random_10)

data_random_10['Manufacturing_Unemployment_Pred'] = pred_random

# %%
# Predict new random unemployment for manufacturing

# Train the model on the training data
model_f.fit(X_train_f, y_train_f)

# Predict on the testing data
pred_random = model_f.predict(data_random_10)

data_random_10['Finance_Unemployment_Pred'] = pred_random

data_random_10
# Out:
#     Year Period  SP500_Return  Percent_Change_in_GDP     CPI  \
# 0   2023    Q01         -0.11                 -16.40  244.45
# 1   2023    Q02          0.06                 -12.07  278.60
# 2   2023    Q03         -0.01                 -17.79  309.32
# 3   2023    Q04          0.13                  11.02  285.51
# 4   2024    Q01          0.12                   7.18  295.33
# 5   2024    Q02         -0.07                   3.85  213.16
# 6   2024    Q03         -0.07                 -17.40  283.26
# 7   2024    Q04          0.13                   5.61  311.66
# 8   2025    Q01          0.19                  -5.67  292.09
# 9   2025    Q02          0.16                   2.85  264.84
# 10  2025    Q03         -0.04                 -14.66  215.66
# 11  2025    Q04          0.02                   7.38  269.45
# 12  2026    Q01          0.09                   5.70  270.23
# 13  2026    Q02          0.10                 -20.66  323.40
# 14  2026    Q03         -0.04                   7.65  254.89
# 15  2026    Q04          0.04                  21.45  263.34
# 16  2027    Q01          0.02                  15.70  265.71
# 17  2027    Q02         -0.17                  22.49  282.68
# 18  2027    Q03          0.12                  24.55  214.39
# 19  2027    Q04          0.16                  16.92  294.14
# 20  2028    Q01         -0.04                  -7.03  288.75
# 21  2028    Q02          0.06                   8.36  290.10
# 22  2028    Q03         -0.15                   1.40  282.27
# 23  2028    Q04         -0.04                 -10.99  264.04
# 24  2029    Q01          0.18                  -3.05  333.33
# 25  2029    Q02          0.07                 -18.23  222.49
# 26  2029    Q03         -0.03                   0.32  202.03
# 27  2029    Q04          0.13                  25.73  281.65
# 28  2030    Q01         -0.06                 -14.02  210.07
# 29  2030    Q02          0.04                 -14.93  318.01
# 30  2030    Q03          0.16                  14.29  250.49
# 31  2030    Q04         -0.01                   6.40  222.57
# 32  2031    Q01          0.13                   1.30  265.10
# 33  2031    Q02         -0.12                 -14.24  298.91
# 34  2031    Q03          0.09                 -10.14  314.16
# 35  2031    Q04          0.09                  21.47  236.86
# 36  2032    Q01         -0.09                  -1.19  234.89
# 37  2032    Q02          0.18                   4.48  233.94
# 38  2032    Q03         -0.01                 -19.65  307.52
# 39  2032    Q04          0.17                  -7.04  299.70
#
#     Construction_Unemployment_Pred  Manufacturing_Unemployment_Pred  \
# 0                        10.642375                         2.319562
# 1                         4.225974                        -0.356270
# 2                        -0.959210                        -3.044149
# 3                         3.938630                        -0.941353
# 4                         5.771195                        -2.377653
# 5                        11.733085                         5.500135
# 6                         1.867263                        -0.685794
# 7                         0.978199                        -3.295432
# 8                         5.745216                        -2.010420
# 9                         6.093751                         0.844427
# 10                        9.200615                         5.457433
# 11                        5.591109                         0.516833
# 12                        8.435081                        -0.092508
# 13                       -0.837012                        -4.385165
# 14                        5.603831                         1.784386
# 15                        6.633216                         1.010949
# 16                        9.215914                         0.259549
# 17                        4.804306                        -0.929890
# 18                       10.385212                         5.419672
# 19                        3.167409                        -1.748541
# 20                        6.124056                        -1.741913
# 21                        3.557096                        -1.497586
# 22                        2.515471                        -0.697644
# 23                        5.677717                         1.083597
# 24                        1.388462                        -5.776603
# 25                       10.082527                         4.779307
# 26                       11.078642                         6.629705
# 27                        4.761708                        -0.658554
# 28                       14.390642                         5.445597
# 29                       -0.083696                        -3.932283
# 30                        6.210848                         2.190105
# 31                       10.609521                         4.781288
# 32                        8.854251                         0.401953
# 33                        2.028189                        -2.226706
# 34                       -1.292102                        -3.501952
# 35                        9.466988                         3.429182
# 36                       12.086885                         3.122272
# 37                        9.454733                         3.651885
# 38                       -0.817389                        -2.871728
# 39                        1.902409                        -2.141187
#
#     Finance_Unemployment_Pred
# 0                    3.015243
# 1                   -0.004223
# 2                   -2.215976
# 3                   -0.715991
# 4                   -1.812712
# 5                    5.393423
# 6                    0.018499
# 7                   -2.807365
# 8                   -1.492251
# 9                    0.800043
# 10                   5.517826
# 11                   0.816989
# 12                   0.320856
# 13                  -3.654872
# 14                   2.008297
# 15                   1.119331
# 16                   0.675493
# 17                  -0.421767
# 18                   4.905421
# 19                  -1.544736
# 20                  -0.858349
# 21                  -1.202871
# 22                  -0.010865
# 23                   1.577125
# 24                  -4.911979
# 25                   4.685659
# 26                   6.444342
# 27                  -0.577401
# 28                   5.748411
# 29                  -3.191096
# 30                   1.992995
# 31                   4.741422
# 32                   0.738491
# 33                  -1.385965
# 34                  -2.857419
# 35                   3.229561
# 36                   3.588289
# 37                   3.299832
# 38                  -2.044720
# 39                  -1.725328
