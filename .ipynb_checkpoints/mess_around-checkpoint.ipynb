# %%
import pandas as pd 
import numpy as np

# %%
merged = pd.read_csv('inputs/merged.csv')
merged.describe()
# Out:
#               Year  SP500_Return  Percent_Change_in_GDP         CPI  \
# count    72.000000     72.000000              72.000000   72.000000
# mean   2013.500000      0.019360               1.988889  234.864106
# std       5.224536      0.083256               6.020003   24.654914
# min    2005.000000     -0.224100             -29.900000  192.366667
# 25%    2009.000000     -0.011650               0.925000  216.656917
# 50%    2013.500000      0.032450               2.350000  234.758833
# 75%    2018.000000      0.062175               3.300000  250.930833
# max    2022.000000      0.241100              35.300000  298.525000
#
#        Construction_Unemployment_Rate  Manufacturing_Unemployment_Rate  \
# count                       72.000000                        72.000000
# mean                         9.511111                         5.663889
# std                          5.178519                         2.703431
# ...
